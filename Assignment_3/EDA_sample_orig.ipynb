# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("historical_data1_Q12007_after_cleaning.csv")

# %%
df.head(10)
# Out:
#    CREDIT_SCORE  FIRST_TIME_HOMEBUYER_FLAG           MSA  \
# 0         722.0                          0  30611.265416
# 1         759.0                          0  30611.265416
# 2         591.0                          0  39100.000000
# 3         792.0                          0  39100.000000
# 4         725.0                          0  48864.000000
# 5         788.0                          0  30611.265416
# 6         691.0                          0  30611.265416
# 7         687.0                          0  30611.265416
# 8         784.0                          0  30611.265416
# 9         703.0                          0  30611.265416
#
#    MORTGAGE_INSURANCE_PERCENTAGE  NUMBER_OF_UNITS OCCUPANCY_STATUS  \
# 0                            0.0                1                P
# 1                            0.0                1                P
# 2                            0.0                1                P
# 3                            0.0                1                P
# 4                            0.0                1                P
# 5                            0.0                1                P
# 6                           35.0                1                P
# 7                            0.0                1                P
# 8                            0.0                1                P
# 9                            0.0                1                P
#
#    ORIGINAL_COMBINED_LOAN_TO_VALUE  ORIGINAL_DEBT_TO_INCOME_RATIO  \
# 0                             80.0                           48.0
# 1                             25.0                           25.0
# 2                             48.0                           34.0
# 3                             90.0                           33.0
# 4                             49.0                           41.0
# 5                             75.0                           55.0
# 6                             97.0                           48.0
# 7                             40.0                           46.0
# 8                             35.0                           30.0
# 9                             67.0                           53.0
#
#    ORIGINAL_UPB  ORIGINAL_LOAN_TO_VALUE         ...           \
# 0         62000                    80.0         ...
# 1        198000                    25.0         ...
# 2        100000                    48.0         ...
# 3        334000                    80.0         ...
# 4        125000                    49.0         ...
# 5        145000                    75.0         ...
# 6         73000                    97.0         ...
# 7         61000                    40.0         ...
# 8         80000                    35.0         ...
# 9        100000                    67.0         ...
#
#    LOAN_SEQUENCE_NUMBER LOAN_PURPOSE  ORIGINAL_LOAN_TERM NUMBER_OF_BORROWERS  \
# 0          F105Q1000064            P                 360                 2.0
# 1          F105Q1000076            N                 360                 2.0
# 2          F105Q1000087            C                 360                 2.0
# 3          F105Q1000130            P                 360                 2.0
# 4          F105Q1000195            N                 360                 2.0
# 5          F105Q1000217            N                 360                 2.0
# 6          F105Q1000227            P                 360                 2.0
# 7          F105Q1000261            P                 360                 2.0
# 8          F105Q1000282            C                 360                 2.0
# 9          F105Q1000305            P                 360                 2.0
#
#      SELLER_NAME        SERVICER_NAME FIRST_PAYMENT_Year FIRST_PAYMENT_Month  \
# 0  Other sellers      Other servicers               2005                   4
# 1  Other sellers  PNCMTGESERVICES,INC               2005                   3
# 2  Other sellers      Other servicers               2005                   4
# 3  Other sellers      Other servicers               2005                   3
# 4  Other sellers             USBANKNA               2005                   3
# 5  Other sellers    WELLSFARGOBANK,NA               2005                   3
# 6  Other sellers      Other servicers               2005                   3
# 7  Other sellers    WELLSFARGOBANK,NA               2005                   3
# 8  Other sellers      Other servicers               2005                   3
# 9  Other sellers      Other servicers               2005                   3
#
#    MATURITY_DATE_Year  MATURITY_DATE_Month
# 0                2035                    3
# 1                2035                    2
# 2                2035                    3
# 3                2035                    2
# 4                2035                    2
# 5                2035                    2
# 6                2035                    2
# 7                2035                    2
# 8                2035                    2
# 9                2035                    2
#
# [10 rows x 26 columns]

# %% [markdown]
# ##### Show the range of every feature.

# %%
plt.figure(figsize = (10,8))
plt.scatter(range(df.shape[0]),np.sort(df.ORIGINAL_COMBINED_LOAN_TO_VALUE.values))
plt.xlabel('index',fontsize=12)
plt.ylabel('ORIGINAL_COMBINED_LOAN_TO_VALUE',fontsize=12)
plt.show()

# %% [markdown]
# ##### Calculate correlation value between features and draw Relation Plot

# %%
corrData = df.corr()

# %%
plt.subplots(figsize=(14, 14))
sns.heatmap(corrData, annot=True, vmax=1, square=True, cmap="Blues")
#plt.savefig('./RelationPlot.png')
plt.show()

# %% [markdown]
# ##### Draw the plot to have a look on every feature's distribution.

# %%
plt.figure(figsize=(18,10))
sns.distplot(df.ORIGINAL_DEBT_TO_INCOME_RATIO.values, bins=50, kde=False)
plt.xlabel('ORIGINAL_DEBT_TO_INCOME_RATIO', fontsize=12)
plt.show()
# Out:
# /Users/G/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.figure(figsize=(20,10))
sns.countplot(x="PROPERTY_STATE", data = df, palette="Set3")

# %%
plt.figure(figsize=(700,10))
sns.countplot(x="POSTAL_CODE", data = df, palette="Set3")
