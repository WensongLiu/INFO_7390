# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('historical_data1_Q12007.txt',sep = '|',dtype = 'str', 
                     names = ["CREDIT_SCORE","FIRST_PAYMENT_DATE","FIRST_TIME_HOMEBUYER_FLAG","MATURITY_DATE","MSA","MORTGAGE_INSURANCE_PERCENTAGE","NUMBER_OF_UNITS","OCCUPANCY_STATUS","ORIGINAL_COMBINED_LOAN_TO_VALUE","ORIGINAL_DEBT_TO_INCOME_RATIO","ORIGINAL_UPB","ORIGINAL_LOAN_TO_VALUE","ORIGINAL_INTEREST_RATE","CHANNEL","PREPAYMENT_PENALTY_MORTGAGE_FLAG","PRODUCT_TYPE","PROPERTY_STATE","PROPERTY_TYPE","POSTAL_CODE","LOAN_SEQUENCE_NUMBER","LOAN_PURPOSE","ORIGINAL_LOAN_TERM","NUMBER_OF_BORROWERS","SELLER_NAME","SERVICER_NAME","Pre_HARP_LOAN_SEQUENCE_NUMBER"])

# %%
df3['ORIGINAL_INTEREST_RATE'] = df3['ORIGINAL_INTEREST_RATE'].astype('float64')
# df1['ORIGINAL_INTEREST_RATE'].mean()

# %%
df3['ORIGINAL_INTEREST_RATE'].mean()
# Out:
# 6.3574405486378485

# %%
df1 = pd.read_csv('historical_data1_Q22007.txt',sep = '|',dtype = 'str', 
                     names = ["CREDIT_SCORE","FIRST_PAYMENT_DATE","FIRST_TIME_HOMEBUYER_FLAG","MATURITY_DATE","MSA","MORTGAGE_INSURANCE_PERCENTAGE","NUMBER_OF_UNITS","OCCUPANCY_STATUS","ORIGINAL_COMBINED_LOAN_TO_VALUE","ORIGINAL_DEBT_TO_INCOME_RATIO","ORIGINAL_UPB","ORIGINAL_LOAN_TO_VALUE","ORIGINAL_INTEREST_RATE","CHANNEL","PREPAYMENT_PENALTY_MORTGAGE_FLAG","PRODUCT_TYPE","PROPERTY_STATE","PROPERTY_TYPE","POSTAL_CODE","LOAN_SEQUENCE_NUMBER","LOAN_PURPOSE","ORIGINAL_LOAN_TERM","NUMBER_OF_BORROWERS","SELLER_NAME","SERVICER_NAME","Pre_HARP_LOAN_SEQUENCE_NUMBER"])

# %%
df2 = pd.read_csv('historical_data1_Q32007.txt',sep = '|',dtype = 'str', 
                     names = ["CREDIT_SCORE","FIRST_PAYMENT_DATE","FIRST_TIME_HOMEBUYER_FLAG","MATURITY_DATE","MSA","MORTGAGE_INSURANCE_PERCENTAGE","NUMBER_OF_UNITS","OCCUPANCY_STATUS","ORIGINAL_COMBINED_LOAN_TO_VALUE","ORIGINAL_DEBT_TO_INCOME_RATIO","ORIGINAL_UPB","ORIGINAL_LOAN_TO_VALUE","ORIGINAL_INTEREST_RATE","CHANNEL","PREPAYMENT_PENALTY_MORTGAGE_FLAG","PRODUCT_TYPE","PROPERTY_STATE","PROPERTY_TYPE","POSTAL_CODE","LOAN_SEQUENCE_NUMBER","LOAN_PURPOSE","ORIGINAL_LOAN_TERM","NUMBER_OF_BORROWERS","SELLER_NAME","SERVICER_NAME","Pre_HARP_LOAN_SEQUENCE_NUMBER"])

# %%
df3 = pd.read_csv('historical_data1_Q42007.txt',sep = '|',dtype = 'str', 
                     names = ["CREDIT_SCORE","FIRST_PAYMENT_DATE","FIRST_TIME_HOMEBUYER_FLAG","MATURITY_DATE","MSA","MORTGAGE_INSURANCE_PERCENTAGE","NUMBER_OF_UNITS","OCCUPANCY_STATUS","ORIGINAL_COMBINED_LOAN_TO_VALUE","ORIGINAL_DEBT_TO_INCOME_RATIO","ORIGINAL_UPB","ORIGINAL_LOAN_TO_VALUE","ORIGINAL_INTEREST_RATE","CHANNEL","PREPAYMENT_PENALTY_MORTGAGE_FLAG","PRODUCT_TYPE","PROPERTY_STATE","PROPERTY_TYPE","POSTAL_CODE","LOAN_SEQUENCE_NUMBER","LOAN_PURPOSE","ORIGINAL_LOAN_TERM","NUMBER_OF_BORROWERS","SELLER_NAME","SERVICER_NAME","Pre_HARP_LOAN_SEQUENCE_NUMBER"])

# %%
df.head()
# Out:
#   CREDIT_SCORE FIRST_PAYMENT_DATE FIRST_TIME_HOMEBUYER_FLAG MATURITY_DATE  \
# 0          691             200705                         9        203704
# 1          620             200705                         9        203704
# 2          644             200703                         Y        203702
# 3          757             200703                         N        203702
# 4          800             200703                         N        203702
#
#      MSA MORTGAGE_INSURANCE_PERCENTAGE NUMBER_OF_UNITS OCCUPANCY_STATUS  \
# 0  40380                           000               1                P
# 1  44140                           000               1                P
# 2  35644                           000               2                P
# 3    NaN                           000               1                P
# 4    NaN                           000               1                P
#
#   ORIGINAL_COMBINED_LOAN_TO_VALUE ORIGINAL_DEBT_TO_INCOME_RATIO  \
# ...

# %%
df.dtypes
# Out:
# CREDIT_SCORE                          int64
# FIRST_PAYMENT_DATE                    int64
# FIRST_TIME_HOMEBUYER_FLAG            object
# MATURITY_DATE                         int64
# MSA                                 float64
# MORTGAGE_INSURANCE_PERCENTAGE         int64
# NUMBER_OF_UNITS                       int64
# OCCUPANCY_STATUS                     object
# ORIGINAL_COMBINED_LOAN_TO_VALUE       int64
# ORIGINAL_DEBT_TO_INCOME_RATIO         int64
# ORIGINAL_UPB                          int64
# ORIGINAL_LOAN_TO_VALUE                int64
# ORIGINAL_INTEREST_RATE              float64
# CHANNEL                              object
# PREPAYMENT_PENALTY_MORTGAGE_FLAG     object
# PRODUCT_TYPE                         object
# PROPERTY_STATE                       object
# PROPERTY_TYPE                        object
# POSTAL_CODE                         float64
# LOAN_SEQUENCE_NUMBER                 object
# LOAN_PURPOSE                         object
# ...

# %% [markdown]
# ### Convert the numerical columns from object to numerical

# %%
df['CREDIT_SCORE'] = df['CREDIT_SCORE'].astype('int64')
df['FIRST_PAYMENT_DATE'] = df['FIRST_PAYMENT_DATE'].astype('int64')
df['MATURITY_DATE'] = df['MATURITY_DATE'].astype('int64')
df['MORTGAGE_INSURANCE_PERCENTAGE'] = df['MORTGAGE_INSURANCE_PERCENTAGE'].astype('int64')
df['NUMBER_OF_UNITS'] = df['NUMBER_OF_UNITS'].astype('int64')
df['ORIGINAL_COMBINED_LOAN_TO_VALUE'] = df['ORIGINAL_COMBINED_LOAN_TO_VALUE'].astype('int64')
df['ORIGINAL_DEBT_TO_INCOME_RATIO'] = df['ORIGINAL_DEBT_TO_INCOME_RATIO'].astype('int64')
df['ORIGINAL_UPB'] = df['ORIGINAL_UPB'].astype('int64')
df['ORIGINAL_LOAN_TO_VALUE'] = df['ORIGINAL_LOAN_TO_VALUE'].astype('int64')
df['ORIGINAL_LOAN_TERM'] = df['ORIGINAL_LOAN_TERM'].astype('int64')
df['NUMBER_OF_BORROWERS'] = df['NUMBER_OF_BORROWERS'].astype('int64')

# %%
df['MSA'] = df['MSA'].astype('float64')
df['ORIGINAL_INTEREST_RATE'] = df['ORIGINAL_INTEREST_RATE'].astype('float64')
df['POSTAL_CODE'] = df['POSTAL_CODE'].astype('float64')
df['Pre_HARP_LOAN_SEQUENCE_NUMBER'] = df['Pre_HARP_LOAN_SEQUENCE_NUMBER'].astype('float64')

# %%
df.describe()
# Out:
#         CREDIT_SCORE  FIRST_PAYMENT_DATE  MATURITY_DATE            MSA  \
# count  303804.000000       303804.000000  303804.000000  253315.000000
# mean      729.224418       200704.475112  203527.196163   30099.936332
# std       242.325431            7.635916     470.535036   11421.243622
# min       300.000000       200701.000000  201202.000000   10180.000000
# 25%       681.000000       200703.000000  203702.000000   19124.000000
# 50%       728.000000       200704.000000  203703.000000   31140.000000
# 75%       772.000000       200705.000000  203704.000000   39580.000000
# max      9999.000000       201605.000000  205407.000000   49740.000000
#
#        MORTGAGE_INSURANCE_PERCENTAGE  NUMBER_OF_UNITS  \
# count                  303804.000000    303804.000000
# mean                        3.466551         1.030293
# std                         9.031889         0.281688
# min                         0.000000         1.000000
# ...

# %% [markdown]
# ### Show the range of every feature.
# #### (Check for outliers)

# %%
plt.figure(figsize = (10,6))
plt.scatter(range(df.shape[0]),np.sort(df.ORIGINAL_COMBINED_LOAN_TO_VALUE.values))
plt.xlabel('index',fontsize=12)
plt.ylabel('ORIGINAL_COMBINED_LOAN_TO_VALUE',fontsize=12)
plt.show()

# %% [markdown]
# #### <font color='green'> SUMMARY: We can check for outliers of different variables using this plot, from the above plot, there is no outlier for ORIGINAL_COMBINED_LOAN_TO_VALUE cause all the values is consequent.</font>

# %% [markdown]
# ### Calculate correlation value between features and draw Relation Plot

# %%
corrData = df.corr()

# %%
plt.subplots(figsize=(14, 14))
sns.heatmap(corrData, annot=True, vmax=1, square=True, cmap="Blues")
plt.show()

# %% [markdown]
# #### <font color='green'>SUMMARY: The above plot indicate the correlation between different features(all of the fifteen numerical variables). We can find that the correlation between some of the features is very high, such as ORIGINAL_LOAN_TO_VALUE and ORIGINAL_COMBINED_LOAN_TO_VALUE(which is 0.94), as well as ORGINAL_LOAN_TO_VALUE and MORTGAGE_INSURANCE-PERCENTAGE(which is 0.44).<br/><br/>For the feature we concerned most--ORIGINAL_INTEREST_RATE, it has a relatively high correlation with MUTURITY_DATE, MORTGAGE_INSURANCE_PERCENTAGE, ORIGINAL_UPB and ORGINAL_LOAN_TERM.</font>

# %% [markdown]
# ### Draw the plot to have a look on every feature's distribution.

# %%
df['CREDIT_SCORE'].fillna(df['CREDIT_SCORE'].mean())
# Out:
# 0         691
# 1         620
# 2         644
# 3         757
# 4         800
# 5         704
# 6         728
# 7         745
# 8         606
# 9         778
# 10        700
# 11        769
# 12        722
# 13        717
# 14        734
# 15        675
# 16        775
# 17        665
# 18        712
# 19        744
# 20        684
# 21        766
# 22        790
# 23        804
# 24        758
# 25        659
# 26        764
# 27        698
# 28        655
# 29        812
#          ...
# 303774    666
# 303775    657
# 303776    724
# 303777    635
# 303778    710
# 303779    734
# 303780    748
# 303781    763
# 303782    715
# 303783    803
# 303784    754
# 303785    756
# 303786    746
# 303787    727
# 303788    694
# 303789    791
# 303790    657
# 303791    669
# 303792    705
# 303793    769
# 303794    779
# 303795    627
# 303796    738
# 303797    658
# 303798    631
# 303799    751
# 303800    698
# 303801    797
# 303802    696
# 303803    697
# ...

# %%
plt.figure(figsize=(18,10))
sns.distplot(df.CREDIT_SCORE.values, bins=50, kde=False)
plt.xlabel('CREDIT_SCORE', fontsize=12)
plt.show()
# Out:
# C:\Users\butte\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ### Leverage STATE and POSTAL_CODE to see location information

# %%
plt.figure(figsize=(20,10))
sns.countplot(x="PROPERTY_STATE", data = df, palette="Set3")

# %%
plt.figure(figsize=(700,10))
sns.countplot(x="POSTAL_CODE", data = df, palette="Set3")

# %%
sns.lmplot('PROPERTY_STATE','ORIGINAL_INTEREST_RATE',df,fit_reg=False, size=12)
plt.show()

# %%
sns.lmplot('POSTAL_CODE','ORIGINAL_INTEREST_RATE',df,fit_reg=False, size=10)
plt.show()

# %% [markdown]
# ### <font color='red'> View trends over time</font>

# %%
# read csv file to a dataframe
def read_csv(file_name):
    return pd.read_csv(file_name, sep = '|', dtype = 'str', 
                       names = ["CREDIT_SCORE","FIRST_PAYMENT_DATE","FIRST_TIME_HOMEBUYER_FLAG","MATURITY_DATE","MSA","MORTGAGE_INSURANCE_PERCENTAGE","NUMBER_OF_UNITS","OCCUPANCY_STATUS","ORIGINAL_COMBINED_LOAN_TO_VALUE","ORIGINAL_DEBT_TO_INCOME_RATIO","ORIGINAL_UPB","ORIGINAL_LOAN_TO_VALUE","ORIGINAL_INTEREST_RATE","CHANNEL","PREPAYMENT_PENALTY_MORTGAGE_FLAG","PRODUCT_TYPE","PROPERTY_STATE","PROPERTY_TYPE","POSTAL_CODE","LOAN_SEQUENCE_NUMBER","LOAN_PURPOSE","ORIGINAL_LOAN_TERM","NUMBER_OF_BORROWERS","SELLER_NAME","SERVICER_NAME","Pre_HARP_LOAN_SEQUENCE_NUMBER"])

# %%
# calculate the mean value of interest rate of different dataframe
def cal_mean_rate(dataframe, mean_list):
    dataframe['ORIGINAL_INTEREST_RATE'] =  dataframe['ORIGINAL_INTEREST_RATE'].astype('float64')
    mean_rate = dataframe['ORIGINAL_INTEREST_RATE'].mean()
    mean_list.append(mean_rate)
    return mean_list

# %%
df4 = read_csv('historical_data1_Q12008.txt')

# %%
cal_mean_rate(df4, rate_mean_list)
print(rate_mean_list)
# Out:
# [6.206374675777705, 6.293963320921612, 6.6635223125059015, 6.3574405486378485, 5.878392174247184]

# %%
df5 = read_csv('historical_data1_Q22008.txt')
df6 = read_csv('historical_data1_Q32008.txt')
df7 = read_csv('historical_data1_Q42008.txt')
df8 = read_csv('historical_data1_Q12009.txt')
df9 = read_csv('historical_data1_Q22009.txt')
df10 = read_csv('historical_data1_Q32009.txt')
df11 = read_csv('historical_data1_Q42009.txt')

# %%
cal_mean_rate(df5, rate_mean_list)
cal_mean_rate(df6, rate_mean_list)
cal_mean_rate(df7, rate_mean_list)
cal_mean_rate(df8, rate_mean_list)
cal_mean_rate(df9, rate_mean_list)
cal_mean_rate(df10, rate_mean_list)
cal_mean_rate(df11, rate_mean_list)
print(rate_mean_list)
# Out:
# [6.206374675777705, 6.293963320921612, 6.6635223125059015, 6.3574405486378485, 5.878392174247184, 6.023503323113953, 6.418909852396206, 5.909778388664615, 4.939957526354662, 4.849901965309257, 5.125708871459421, 4.926207487996884]

# %%
rate_mean_list = list()

# %%
rate_mean_list.clear()

# %%
rate_mean_list.append(df['ORIGINAL_INTEREST_RATE'].mean())
rate_mean_list.append(df1['ORIGINAL_INTEREST_RATE'].mean())
rate_mean_list.append(df2['ORIGINAL_INTEREST_RATE'].mean())
rate_mean_list.append(df3['ORIGINAL_INTEREST_RATE'].mean())

# %%
time_list = list()

# %%
time_list.append('Q1_2007')

# %%
time_list.append('Q2_2007')
time_list.append('Q3_2007')
time_list.append('Q4_2007')

# %%
time_list.append('Q1_2008')
time_list.append('Q2_2008')
time_list.append('Q3_2008')
time_list.append('Q4_2008')
time_list.append('Q1_2009')
time_list.append('Q2_2009')
time_list.append('Q3_2009')
time_list.append('Q4_2009')
print(time_list)
# Out:
# ['Q1_2007', 'Q2_2007', 'Q3_2007', 'Q4_2007', 'Q1_2008', 'Q2_2008', 'Q3_2008', 'Q4_2008', 'Q1_2009', 'Q2_2009', 'Q3_2009', 'Q4_2009']

# %%
# plt.plot(time_list, rate_mean_list)
fig,ax=plt.subplots(figsize=(20,10))
ax.plot(time_list, rate_mean_list)
ax.set(xlabel='time', ylabel='interest rate',
      title='Interest rate trends over time from 2007 to 2009')
ax.grid()
fig.figure
plt.show()

# %% [markdown]
# #### <font color='green'>SUMMARY: First, we read every quarterly data from 2007 to 2009 as a dataframe, and we calculated the mean value of original interest rate in each quarter. The above figure shows the trends of the interest rate over three years. We can find that the interest rate shows a decreasing trend year by year.</font>

# %%
fig = plt.figure()

for frame in [df, df1, df2, df3]:
    plt.plot(frame['CREDIT_SCORE'],frame['ORIGINAL_INTEREST_RATE'])

plt.xlim(0,10000)
plt.ylim(0,10)
plt.show()

# %% [markdown]
# #### <font color='green'>SUMMARY: We imported the data of Q1_2007-Q4_2007 into four different dataframes(df, df1, df2, df3) and tried to plot them in the same figure to see the trends of features over time.<br/><br/>From the above figure, we found that the original interest rate is basically in a fixed range in the time period from Q1 to Q4 of 2007.</font>

# %%
ax = df.plot()
plt.figure(figsize=(20,20))
df1.plot(ax=ax)
df2.plot(ax=ax)
plt.show()

# %%
fig1 = plt.figure()
ax = fig1.add_subplot(111)

ax.plot(df['ORIGINAL_INTEREST_RATE'])
ax.plot(df1['ORIGINAL_INTEREST_RATE'])

# %%
# def cal_mean_rate(dataframe):
#     for col in dataframe.columns.tolist():
#         if col== 'ORGINAL_INTEREST_RATE':
#             print(dataframe[col].mean())
#             return dataframe[col].mean()
#         else:
#             pass
