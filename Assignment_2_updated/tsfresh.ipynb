# %%
import pandas as pd
from tsfresh import extract_features

# %%
df = pd.read_csv('energydata_complete.csv')
df.head(10)
# Out:
#                   date  Appliances  lights         T1       RH_1     T2  \
# 0  2016-01-11 17:00:00          60      30  19.890000  47.596667  19.20
# 1  2016-01-11 17:10:00          60      30  19.890000  46.693333  19.20
# 2  2016-01-11 17:20:00          50      30  19.890000  46.300000  19.20
# 3  2016-01-11 17:30:00          50      40  19.890000  46.066667  19.20
# 4  2016-01-11 17:40:00          60      40  19.890000  46.333333  19.20
# 5  2016-01-11 17:50:00          50      40  19.890000  46.026667  19.20
# 6  2016-01-11 18:00:00          60      50  19.890000  45.766667  19.20
# 7  2016-01-11 18:10:00          60      50  19.856667  45.560000  19.20
# 8  2016-01-11 18:20:00          60      40  19.790000  45.597500  19.20
# 9  2016-01-11 18:30:00          70      40  19.856667  46.090000  19.23
#
#         RH_2     T3       RH_3         T4    ...             T9   RH_9  \
# 0  44.790000  19.79  44.730000  19.000000    ...      17.033333  45.53
# ...

# %%
X = extract_features(df,column_id='Appliances', column_sort='date')
print(X)
X.head(5)
# Out:
# Feature Extraction: 100%|███████████████████████████████████████████████████████████| 10/10 [1:07:47<00:00, 937.26s/it]
# variable  Press_mm_hg__abs_energy  Press_mm_hg__absolute_sum_of_changes  \
# id
# 10                   5.199594e+06                             38.783333
# 20                   1.973399e+08                            456.544444
# 30                   4.150120e+08                            582.914286
# 40                   1.156222e+09                            771.038889
# 50                   2.496053e+09                            820.394444
# 60                   1.871634e+09                            822.966667
# 70                   8.895402e+08                            779.916667
# 80                   6.872088e+08                            737.183333
# 90                   5.782646e+08                            725.200000
# 100                  5.562921e+08                            725.866667
# ...

# %% [markdown]
# ### conclusion

# %% [markdown]
# We tried to select a probable column_id from our dataset. At first, we think even though there is not a id in our dataset, maybe we can choose from any of the numerical column. We tried them, the result in the above cell showed the calculation result using "Appliances" as id. However, the result is weired. In summary, we do not think tsfresh is a usable feature engineering tool for the energy consumption prediction dataset.
